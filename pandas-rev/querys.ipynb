# %%
import pandas as pd

# %%
df1= pd.read_csv('train.csv')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.query('Survived == 1')[['Name', 'Age']]
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ..                                                 ...   ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 889                              Behr, Mr. Karl Howell  26.0
#
# [342 rows x 2 columns]

# %%
# Quando o tipo for string, tem que estar entre aspas opostas 
df1.query('Sex == "female"')[['Name', 'Age']]
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ..                                                 ...   ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 882                       Dahlberg, Miss. Gerda Ulrika  22.0
# 885               Rice, Mrs. William (Margaret Norton)  39.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
#
# [314 rows x 2 columns]

# %%
df1.query('Age >= 40 & Sex == "female"')[['Name', 'Age']]
# Out:
#                                                   Name   Age
# 11                            Bonnell, Miss. Elizabeth  58.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   55.0
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0
# 132     Robins, Mrs. Alexander A (Grace Charity Laury)  47.0
# 161  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  40.0
# 167    Skoog, Mrs. William (Anna Bernhardina Karlsson)  45.0
# 177                         Isham, Miss. Ann Elizabeth  50.0
# 194          Brown, Mrs. James Joseph (Margaret Tobin)  44.0
# 195                               Lurette, Miss. Elise  58.0
# 254           Rosblom, Mrs. Viktor (Helena Wilhelmina)  41.0
# 259                        Parrish, Mrs. (Lutie Davis)  50.0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  58.0
# 272          Mellinger, Mrs. (Elizabeth Anne Maidment)  41.0
# ...

# %%
# Precisamos usar @ para referenciar a variavel dentro da query
idade = 20

df1.query('Age >= @idade')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
