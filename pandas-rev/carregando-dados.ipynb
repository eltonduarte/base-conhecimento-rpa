# %% [markdown]
# Fontes de dados: Kaggle, UCI, Dados Gov.

# %%
Dados do Titanic

# %%
import pandas as pd

# %%
dados = pd.read_csv('train.csv')

# %%
dados
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dados.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
dados.shape # linhas x colunas
# Out:
# (891, 12)

# %%
dados.info() # ver os tipos das colunas, objeto é igual texto
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ...
# # Manipulando Colunas

# %%
dados.columns # Lista com o nome de todas as colunas
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dados['Survived'] # dados das colunas
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(dados['Survived'])
# Out:
# pandas.core.series.Series

# %%
# Cada coluna dentro do pandas é uma Series, parecido com dicionário, temos 1 chave e abaixo da chave uma lista de valores dessa respectiva chave.

# %%
dados.rename(columns={'PassengerId': 'Id do Passageiro'}, inplace = True) # renomei a coluna especifica, inplace mantém a alteração

# %%
dados
# Out:
#      Id do Passageiro  Survived  Pclass  \
# 0                   1         0       3
# 1                   2         1       1
# 2                   3         1       3
# 3                   4         1       1
# 4                   5         0       3
# ..                ...       ...     ...
# 886               887         0       2
# 887               888         1       1
# 888               889         0       3
# 889               890         1       1
# 890               891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# copiando um dataframe para outro

dados_copia = dados.copy()
dados_copia
# Out:
#      Id do Passageiro  Survived  Pclass  \
# 0                   1         0       3
# 1                   2         1       1
# 2                   3         1       3
# 3                   4         1       1
# 4                   5         0       3
# ..                ...       ...     ...
# 886               887         0       2
# 887               888         1       1
# 888               889         0       3
# 889               890         1       1
# 890               891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# renomeando o nome de todas as colunas
dados_copia.rename(columns={'PassengerId':'Id Passageiro', 'Survived':'Sobreviveu', 'Pclass':'Classe', 
                            'Name':'Nome', 'Sex':'Sexo', 'Age':'Idade', 'SibSp':'Membros Familia',
                            'Parch':'Pais Filhos a Bordo', 'Ticket':'Bilhete', 'Fare':'Valor Passagem', 
                            'Cabin':'Cabine', 'Embarked':'Portao de Embarque'}, inplace=True)

# %%
dados_copia
# Out:
#      Id do Passageiro  Sobreviveu  Classe  \
# 0                   1           0       3
# 1                   2           1       1
# 2                   3           1       3
# 3                   4           1       1
# 4                   5           0       3
# ..                ...         ...     ...
# 886               887           0       2
# 887               888           1       1
# 888               889           0       3
# 889               890           1       1
# 890               891           0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ...

# %%
for i in dados_copia.columns:
    print(i)
# Out:
# Id do Passageiro
# Sobreviveu
# Classe
# Nome
# Sexo
# Idade
# Membros Familia
# Pais Filhos a Bordo
# Bilhete
# Valor Passagem
# Cabine
# Portao de Embarque

# %%
# Excluindo uma couna, podemos passar varias colunas

del dados_copia['Id do Passageiro']

# %%
dados_copia
# Out:
#      Sobreviveu  Classe                                               Nome  \
# 0             0       3                            Braund, Mr. Owen Harris
# 1             1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2             1       3                             Heikkinen, Miss. Laina
# 3             1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4             0       3                           Allen, Mr. William Henry
# ..          ...     ...                                                ...
# 886           0       2                              Montvila, Rev. Juozas
# 887           1       1                       Graham, Miss. Margaret Edith
# 888           0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889           1       1                              Behr, Mr. Karl Howell
# 890           0       3                                Dooley, Mr. Patrick
#
# ...

# %%
dados_copia2= dados.copy()

# %%
# Podemos apagar colunas com o drop, que recebe uma lista com o nome das colunas, 
# Axis(eixo) por padrao é 0 para linha, e 1 coluna 


dados_copia2.drop(['Id do Passageiro', 'Survived'], axis=1, inplace=True)

# %%
dados_copia2
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %% [markdown]
# ...
# # Filtrando Dados
